# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from math import factorial

# %%
# Задание 1 - нарисовать квадрат 
fig, ax = plt.subplots()
square = matplotlib.patches.Rectangle((-1, -1), 2, 2, fill=True)
ax.add_patch(square)
plt.axis([-2, 2, -1.2, 1.2])
plt.show()

# %%
# Задание 2 - построить по точкам синус
x = x = np.linspace(0, 2*np.pi, 50)
plt.axis([0, 7, -1.2, 1.2])
plt.scatter(x, np.sin(x))
plt.show()

# %%
# Задание 3 - гистограмма 
lam = 10

dots = np.random.poisson(lam, 100000)
maxDot = max(poi)
plt.hist(dots, maxDot, density=1, facecolor='g', alpha=0.75)

x = range(maxDot)
y = []
for i in range(maxDot):
    y.append((lam**i * np.exp(-lam)) / factorial(i))


plt.plot(x, y, '--')
plt.text(0, .12, r'$\lam=1.5')
plt.grid(True)
plt.show()
